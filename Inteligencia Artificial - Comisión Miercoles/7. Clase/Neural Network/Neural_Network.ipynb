# %%
#Importamos las librerias!
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
#Fijamos una semilla aleatoria para la reproducibilidad
numpy.random.seed(7)

# %%
#Cargamos los datos
dataset = numpy.loadtxt("C:/Users/Layla/Desktop/Docencia/BA Emprende/Programa Inteligencia Artificial/7. Clase/Neural Network/pima-indians-diabetes.csv", delimiter=",")
print(dataset)
# Out:
# [[  6.    148.     72.    ...   0.627  50.      1.   ]
#  [  1.     85.     66.    ...   0.351  31.      0.   ]
#  [  8.    183.     64.    ...   0.672  32.      1.   ]
#  ...
#  [  5.    121.     72.    ...   0.245  30.      0.   ]
#  [  1.    126.     60.    ...   0.349  47.      1.   ]
#  [  1.     93.     70.    ...   0.315  23.      0.   ]]

# %%
#Dividido en variables de entrada (X) y salida (Y)
X = dataset[:,0:8]
Y = dataset[:,8]

#Aclaracion: El conjunto de datos tiene 9 columnas y el rango 0:8 seleccionará las columnas de 0 a 7, 
#deteniéndose antes del índice 8 el cual conforma la salida.

# %%
#Creamos el modelo
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu')) 
model.add(Dense(8, activation='relu')) 
model.add(Dense(1, activation='sigmoid'))

#Aclaracion: La primera capa oculta tiene 12 neuronas y espera 8 variables de entrada (p. ej. entrada dim=8). 
#La segunda capa oculta tiene 8 neuronas y finalmente la capa de salida que tiene 1 neurona 
#para predecir la clase (inicio de diabetes o no).

# %% [markdown]
# Aquí podemos ver la estructura de la red neuronal:
#
# ![imagen.png](attachment:imagen.png)

# %%
#Compilamos el modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# En este caso, utilizaremos la pérdida logarítmica, que para un problema de clasificación binaria se define en Keras como “binary_crossentropy”. También utilizaremos el algoritmo de descenso de gradiente eficiente “adam” por su alta eficiencia en estos problemas.
#
# Finalmente, debido a que es un problema de clasificación, recopilaremos y reportaremos la exactitud de la clasificación como la métrica.

# %%
#Ajustamos el modelo
model.fit(X, Y, epochs=150) #Numero de Epocas
# Out:
# Epoch 1/150
# 24/24 [==============================] - 0s 1ms/step - loss: 23.4322 - accuracy: 0.3578
# Epoch 2/150
# 24/24 [==============================] - 0s 1ms/step - loss: 6.0368 - accuracy: 0.4554
# Epoch 3/150
# 24/24 [==============================] - 0s 1ms/step - loss: 2.4648 - accuracy: 0.6335
# Epoch 4/150
# 24/24 [==============================] - 0s 1ms/step - loss: 1.9133 - accuracy: 0.6217
# Epoch 5/150
# 24/24 [==============================] - 0s 954us/step - loss: 1.3905 - accuracy: 0.5895
# Epoch 6/150
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2901 - accuracy: 0.5927
# Epoch 7/150
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1507 - accuracy: 0.6181
# Epoch 8/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9974 - accuracy: 0.5629
# Epoch 9/150
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0261 - accuracy: 0.5714
# Epoch 10/150
# ...

# %%
#Evaluamos el modelo
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 914us/step - loss: 0.5125 - accuracy: 0.7656
#
# accuracy: 76.56%
