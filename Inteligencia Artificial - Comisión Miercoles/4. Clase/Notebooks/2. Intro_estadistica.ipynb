# %% [markdown]
# # Introducción a estadística

# %%
import pandas as pd

# %%
data_spotify=pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')

# %% [markdown]
# ### 1) Estadística descriptiva

# %%
from pandas_profiling import ProfileReport
from funpymodeling.exploratory import status, profiling_num, freq_tbl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-8d3012c760e4> in <module>
# ----> 1 from pandas_profiling import ProfileReport
#       2 from funpymodeling.exploratory import status, profiling_num, freq_tbl
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
status(data_spotify)
# Out:
#                     variable  q_nan     p_nan  q_zeros   p_zeros  unique  \
# 0                   track_id      0  0.000000        0  0.000000   28356
# 1                 track_name      5  0.000152        0  0.000000   23449
# 2               track_artist      5  0.000152        0  0.000000   10692
# 3           track_popularity      0  0.000000     2703  0.082326     101
# 4             track_album_id      0  0.000000        0  0.000000   22545
# 5           track_album_name      5  0.000152        0  0.000000   19743
# 6   track_album_release_date      0  0.000000        0  0.000000    4530
# 7              playlist_name      0  0.000000        0  0.000000     449
# 8                playlist_id      0  0.000000        0  0.000000     471
# 9             playlist_genre      0  0.000000        0  0.000000       6
# 10         playlist_subgenre      0  0.000000        0  0.000000      24
# 11              danceability      0  0.000000        1  0.000030     822
# 12                    energy      0  0.000000        0  0.000000     952
# 13                       key      0  0.000000     3454  0.105199      12
# 14                  loudness      0  0.000000        0  0.000000   10222
# 15                      mode      0  0.000000    14259  0.434289       2
# 16               speechiness      0  0.000000        1  0.000030    1270
# 17              acousticness      0  0.000000        1  0.000030    3731
# 18          instrumentalness      0  0.000000    12089  0.368197    4729
# 19                  liveness      0  0.000000        1  0.000030    1624
# 20                   valence      0  0.000000        1  0.000030    1362
# 21                     tempo      0  0.000000        1  0.000030   17684
# 22               duration_ms      0  0.000000        0  0.000000   19785
#
#        type
# 0    object
# 1    object
# 2    object
# 3     int64
# 4    object
# 5    object
# 6    object
# 7    object
# 8    object
# 9    object
# 10   object
# 11  float64
# 12  float64
# 13    int64
# 14  float64
# 15    int64
# 16  float64
# 17  float64
# 18  float64
# 19  float64
# 20  float64
# 21  float64
# 22    int64

# %%
freq_tbl(data_spotify.playlist_genre)
# Out:
#   playlist_genre  frequency  percentage  cumulative_perc
# 0            edm       6043    0.184053         0.184053
# 1            rap       5746    0.175007         0.359059
# 2            pop       5507    0.167728         0.526787
# 3            r&b       5431    0.165413         0.692200
# 4          latin       5155    0.157007         0.849207
# 5           rock       4951    0.150793         1.000000

# %% [markdown]
# ¿Cuales son los géneros más populares?

# %%
data_spotify.groupby('playlist_genre')['track_popularity'].mean().sort_values(ascending=False)
# Out:
# playlist_genre
# pop      47.744870
# latin    47.026576
# rap      43.215454
# rock     41.728338
# r&b      41.223532
# edm      34.833526
# Name: track_popularity, dtype: float64

# %% [markdown]
# ¿Cuáles son los 5 temas más populares?

# %%
data_spotify.sort_values('track_popularity', ascending=False).head()
# Out:
#                      track_id    track_name    track_artist  track_popularity  \
# 20091  2XU0oxnq2qxCpomAAuJY8K  Dance Monkey     Tones and I               100
# 1551   2XU0oxnq2qxCpomAAuJY8K  Dance Monkey     Tones and I               100
# 30202  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
# 23104  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
# 21468  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
#
#                track_album_id                             track_album_name  \
# 20091  0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 1551   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 30202  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
# 23104  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
# 21468  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
#
#       track_album_release_date  \
# 20091               2019-10-17
# 1551                2019-10-17
# 30202               2019-10-10
# 23104               2019-10-10
# 21468               2019-10-10
#
#                                            playlist_name  \
# 20091                          Global Top 50 | 2020 Hits
# 1551   post-teen alternative, indie, pop (large variety)
# 30202  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23104  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 21468                                 Contemporary Urban
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 20091  1KNl4AYfgZtOVm9KHkhPTF          latin  ...   6    -6.400     0
# 1551   1y42gwI5cuwjBslPyQNfqb            pop  ...   6    -6.400     0
# 30202  3xMQTDLOIGvj3lWH5e5x6F            edm  ...   6    -5.616     0
# 23104  3xMQTDLOIGvj3lWH5e5x6F            r&b  ...   6    -5.616     0
# 21468  6wyJ4bsjZaUKa9f6GeZlAO            r&b  ...   6    -5.616     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 20091       0.0924        0.6920          0.000104     0.149    0.513
# 1551        0.0924        0.6920          0.000104     0.149    0.513
# 30202       0.1480        0.0522          0.000000     0.460    0.457
# 23104       0.1480        0.0522          0.000000     0.460    0.457
# 21468       0.1480        0.0522          0.000000     0.460    0.457
#
#          tempo  duration_ms
# 20091   98.027       209438
# 1551    98.027       209438
# 30202  116.735       163636
# 23104  116.735       163636
# 21468  116.735       163636
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 2) Estadística inferencial

# %% [markdown]
# ### Muestreo de una Población

# %%
#Hago un sampleo! del dataset
muestra_1=data_spotify.sample(n=16000, random_state=1)
muestra_2=data_spotify.sample(n=16000, random_state=2)
muestra_3=data_spotify.sample(n=16000, random_state=3)

# %%
#Promedio para track_popularity muestra_1
muestra_1.track_popularity.mean()
# Out:
# 42.5674375

# %%
#Promedio para track_popularity muestra_2
muestra_2.track_popularity.mean()
# Out:
# 42.55375

# %%
#Promedio para track_popularity muestra_3
muestra_3.track_popularity.mean()
# Out:
# 42.6625625

# %%
muestra_1
# Out:
#                      track_id                  track_name     track_artist  \
# 6192   2P3SLxeQHPqh8qKB6gtJY2              Poetic Justice   Kendrick Lamar
# 3857   2csDp6iJqt8VypzWSFrwwT  Marzipan (If You Love Him)         No Coast
# 32498  1admxCJQrEkYxmjhI0JNmc                Love Rush In     Orjan Nilsen
# 11169  6NPjHwhEG7eQUQBoPFBrnz           Pasado y Presente            Ozuna
# 10774  1iSqfoUFnQwV0QW1EfUit8                    Suicidal        YNW Melly
# ...                       ...                         ...              ...
# 11364  6ceje6UKhygjO1U1TYvv5P                  Sweet Love     Junko Ohashi
# 19302  0r9d60ZYPAlFHq8qnUtkXN    Madura (feat. Bad Bunny)      Cosculluela
# 22253  0vuEcIoQfIs5fAiUJ8qZhv                   Take Over           Gavlyn
# 11969  5LKdAzDeMyMXezSTIHkXcE                  Ça me vexe  Mademoiselle K.
# 8955   4LwU4Vp6od3Sb08CsP99GC            The Next Episode          Dr. Dre
#
#        track_popularity          track_album_id  \
# 6192                 68  3DGQ1iZ9XKUQxAUWjfC34w
# 3857                 16  0odpMWGAW7gZt96OSRrlRQ
# 32498                23  35liK7w1xe6UcihSfge9r6
# 11169                64  0SukGZiXMtmsZoxstkBtNR
# 10774                90  5xq6RMHNIBA73qld03dR6V
# ...                 ...                     ...
# 11364                 0  5RU9fbrAkb9vpigXoit0ci
# 19302                71  23gojwaJJ5vJxFiAQtiTsQ
# 22253                 6  5ov2iFFEF8RQh12Je57z4u
# 11969                40  2uI9jvUZPBUFXiDbpwF9F0
# 8955                 70  7q2B4M5EiBkqrlsNW8lB7N
#
#                       track_album_name track_album_release_date  \
# 6192   good kid, m.A.A.d city (Deluxe)                     2012
# 3857        Marzipan (If You Love Him)               2019-07-08
# 32498                     Love Rush In               2018-12-14
# 11169                             Aura               2018-08-24
# 10774                 Melly vs. Melvin               2019-11-22
# ...                                ...                      ...
# 11364   THE BEST SONGS OF JUNKO OHASHI               1998-12-05
# 19302         Madura (feat. Bad Bunny)               2018-04-13
# 22253                Modest Confidence               2014-01-14
# 11969                       Ça me vexe               2006-08-21
# 8955                              2001               1999-11-16
#
#                                            playlist_name  \
# 6192                                  Hip Hop Controller
# 3857   Indie Poptimism (PUBLIC, The Band CAMINO, love...
# 32498  Fresh EDM | Progressive House | Electro House ...
# 11169                                        Trap 2020 🔥
# 10774                                           Sad Trap
# ...                                                  ...
# 11364                              City Pop 1985 シティーポップ
# 19302                                   Reggaeton Rewind
# 22253                      Urban/Trap - Contemporary RAP
# 11969                                      L' ALBUM ROCK
# 8955                    GTA San Andreas Radio Los Santos
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 6192   37i9dQZF1DWT5MrZnPU1zD            rap  ...   6    -9.985     0
# 3857   69yb02k0ZOmukYaxJXwp76            pop  ...   2    -6.352     1
# 32498  0FCHg9zJMNNiOokh3hVcxd            edm  ...   5    -3.793     0
# 11169  37DFLy7lqF3qiR99Ss2ZGR            rap  ...   0    -2.866     1
# 10774  7kzKtw5vug3IIxKfLadi8A            rap  ...   9    -9.682     0
# ...                       ...            ...  ...  ..       ...   ...
# 11364  3j2osvmecEao5nmo9jZ5df           rock  ...   5    -6.929     0
# 19302  37i9dQZF1DXco4ODkIraMD          latin  ...   1    -7.639     0
# 22253  5CK0fshHcik1vWyeCc0zat            r&b  ...  11    -7.548     1
# 11969  0jilq2XZP9F2fwzp2k6iXK           rock  ...  11    -4.955     0
# 8955   6m0BqpJfSP2m5xCOFjDRHw            rap  ...  10    -2.429     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 6192        0.3780        0.1570          0.000000    0.2460    0.647
# 3857        0.0450        0.0272          0.000003    0.3970    0.398
# 32498       0.2480        0.0240          0.000077    0.7430    0.218
# 11169       0.0535        0.1290          0.001090    0.0906    0.970
# 10774       0.0688        0.3340          0.000000    0.1260    0.235
# ...            ...           ...               ...       ...      ...
# 11364       0.0309        0.2410          0.000000    0.3100    0.656
# 19302       0.2020        0.1380          0.000001    0.1510    0.751
# 22253       0.2410        0.1960          0.000000    0.2170    0.225
# 11969       0.1360        0.1300          0.000003    0.1740    0.221
# 8955        0.2700        0.0281          0.000000    0.0856    0.309
#
#          tempo  duration_ms
# 6192   135.956       300160
# 3857   108.952       181853
# 32498  124.919       180683
# 11169  127.988       221387
# 10774  140.005       222997
# ...        ...          ...
# 11364   93.040       289333
# 19302   88.029       190909
# 22253  119.012       217653
# 11969  140.065       207933
# 8955    95.295       161507
#
# [16000 rows x 23 columns]

# %%
muestra_2
# Out:
#                      track_id  \
# 27688  4XgTgTG9FF7llF5waA0KSE
# 17835  17G9G5tBsdzmKmoHIh00sX
# 24609  1n86eBhlqaxWIwi5YZTUok
# 21573  41L3O37CECZt3N7ziG2z7l
# 2558   6BaCraQ9xeLYg4Sb9TBT2X
# ...                       ...
# 9546   5UQOmTylBEdsIfSn37v3DO
# 28165  2h4QMolhE2puX7CYZyYOmn
# 22622  5r42z9LpkdDAYe3bmbnO5M
# 16154  6jbUknjNdYMr4I5WB1Mmis
# 8019   3H1WufSXLnOPckdJnFDbtF
#
#                                               track_name    track_artist  \
# 27688                                       Sweet & Sour   Mike Williams
# 17835                                   Me Gusta - Remix   Natti Natasha
# 24609                                       I Get Around            2Pac
# 21573                                              Yummy   Justin Bieber
# 2558   Feels (feat. Pharrell Williams, Katy Perry & B...   Calvin Harris
# ...                                                  ...             ...
# 9546                                  Straight Up Menace         MC Eiht
# 28165                                          Disappear    Rob Stepwart
# 22622             Un Bolero Que Te Salve - Remasterizado    Leoni Torres
# 16154                                         Love Hurts        Nazareth
# 8019                            Leflaur Leflah Eshkoshka  Heltah Skeltah
#
#        track_popularity          track_album_id  \
# 27688                 0  4jy8viBbz3dZaYjYbR4Pwz
# 17835                70  1D7lFbv4p8DjJVKOcHfX1r
# 24609                 8  57ewG8zGTf3Thf3v7boDaA
# 21573                95  1SN6N3fNkZk5oXQ9X46QZ3
# 2558                 66  52LQhrLLYOup9HhaOsv54e
# ...                 ...                     ...
# 9546                 56  38BUSePXkHHL9gNyS1weTB
# 28165                13  246E5OvV4QXhPrGOSj7vdb
# 22622                26  4EYZaRvd05NA1IVzJZv8dd
# 16154                 1  0OYxyoXzDB2ybBBU9slmxN
# 8019                 44  2y2mVMtsGw109N65M3NiWO
#
#                                         track_album_name  \
# 27688                                       Sweet & Sour
# 17835                                   Me Gusta (Remix)
# 24609                       Strictly 4 My N.I.G.G.A.Z...
# 21573                                              Yummy
# 2558   Feels (feat. Pharrell Williams, Katy Perry & B...
# ...                                                  ...
# 9546                                 The Best of MC Eiht
# 28165                                       Trip Stories
# 22622                           Latiendo (Remasterizado)
# 16154                                        The Singles
# 8019                                           Nocturnal
#
#       track_album_release_date                                 playlist_name  \
# 27688               2016-03-11                       Jeff Seid Electro House
# 17835               2019-05-01            LATIN POP 2020 🔥 Pop latino actual
# 24609               1993-02-16                Ultimate Throwbacks Collection
# 21573               2020-01-03                      Most Popular 2020 TOP 50
# 2558                2017-06-16                    Electropop Hits  2017-2020
# ...                        ...                                           ...
# 9546                2010-09-21                      Gangsta Rap/90's Hip-Hop
# 28165               2018-11-27                            House Electro 2019
# 22622               2011-02-10                              Cuban vibes only
# 16154               2012-02-20  Hard Rock Classics 1967-1991 (Party Edition)
# 8019                1996-01-01              90's Hip Hop Ultimate Collection
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 27688  2Tisn6NZbeofpc57Oc6MGo            edm  ...   1    -5.510     1
# 17835  2kKzN3kRYDzBctlaWs7CP2          latin  ...   1    -3.527     0
# 24609  1dsaMvnC1hXPCNGC4aVtjj            r&b  ...  10   -13.927     0
# 21573  1fqkbjEACMlekdddm5aobE            r&b  ...   9    -6.554     0
# 2558   7kyvBmlc1uSqsTL0EuNLrx            pop  ...  11    -3.105     0
# ...                       ...            ...  ...  ..       ...   ...
# 9546   62spXXfUxBed8nbd5xvH2O            rap  ...   7    -9.639     1
# 28165  72r6odw0Q3OWTCYMGA7Yiy            edm  ...   1    -5.565     1
# 22622  6VWXakL2ojgiVC01I271e2            r&b  ...   0    -7.135     1
# 16154  1NIX36ZFWEtgXSbSNghoue           rock  ...   7    -6.584     1
# 8019   4IG024zoaGMurhTFBkMAv9            rap  ...  11   -10.879     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 27688       0.0413      0.000113          0.856000    0.1450    0.385
# 17835       0.0401      0.024700          0.000003    0.2720    0.835
# 24609       0.1170      0.152000          0.000018    0.2510    0.633
# 21573       0.1060      0.404000          0.000000    0.1210    0.495
# 2558        0.0571      0.064200          0.000000    0.0943    0.872
# ...            ...           ...               ...       ...      ...
# 9546        0.1420      0.001380          0.007010    0.3230    0.524
# 28165       0.2920      0.280000          0.000000    0.2100    0.535
# 22622       0.0303      0.626000          0.000010    0.0842    0.450
# 16154       0.0245      0.006130          0.007800    0.1130    0.119
# 8019        0.3530      0.023600          0.000000    0.1320    0.698
#
#          tempo  duration_ms
# 27688  127.966       177611
# 17835   96.010       197013
# 24609   96.194       259000
# 21573  145.841       210427
# 2558   101.018       223413
# ...        ...          ...
# 9546    79.855       274307
# 28165  128.049       161250
# 22622  133.939       221000
# 16154   80.071       233013
# 8019    92.062       303299
#
# [16000 rows x 23 columns]

# %%
muestra_3
# Out:
#                      track_id                             track_name  \
# 26607  4jBPWUAtvIbj7trXEg9QPJ                     Darkness and Light
# 13974  1OFKUn2VLafrHj7ybnap0Q                 Only Wanna Be with You
# 16643  0A2g7e4FUHJ5YJq83uyLRF  Hookah & Sheridan's (Bachata Version)
# 30884  05dL7chWJaVjMJnGO1YCKk                            Untouchable
# 3370   0ajxZXbCw3XJRlSVH25wVM                         Juegos de Amor
# ...                       ...                                    ...
# 9306   38yO5JuwYujWm8XBvMOOrk                                    BWA
# 5930   2Yv2mHzr5AQavVdwQjEokV                          Hand Me Downs
# 12080  5d7gSSTkL4syrnxli8dLYJ          Ogre Battle - Remastered 2011
# 6336   1jlnBQGP2DtSEhMgQaz7a7   Haute (feat. J Balvin & Chris Brown)
# 28751  7cuRgdYlesmnGmVaZwhkda                        Rave After Rave
#
#                 track_artist  track_popularity          track_album_id  \
# 26607            John Legend                52  7xMjYDrgPLp1ReFGAOyS1O
# 13974  Hootie & The Blowfish                68  5AYmpTfdv1OoASUJ5rZB7K
# 16643              DJ Khalid                54  4n6wm128CH98FF29p9GHzF
# 30884               Tritonal                53  3SDHTZyc0Bc84ePaIzchrd
# 3370                   Mœnia                49  6y3FTrfW6zFquk2V1qU2as
# ...                      ...               ...                     ...
# 9306                 Olexesh                40  3whvTAIClofWdLa8PviZjc
# 5930              Mac Miller                72  5sY6UIQ32GqwMLAfSNEaXb
# 12080                  Queen                33  0NouBnbXRJKFWzm9LwCW0K
# 6336                    Tyga                67  6hHIX3lfGKnZ2ji41YZMVV
# 28751                    W&W                51  41V55bmGvx8iRO38sl2d6W
#
#                             track_album_name track_album_release_date  \
# 26607                     DARKNESS AND LIGHT               2016-12-02
# 13974                      Cracked Rear View               1994-07-01
# 16643  Hookah & Sheridan's (Bachata Version)               2019-02-22
# 30884                            Untouchable               2015-05-18
# 3370                             Stereo Hits                     2005
# ...                                      ...                      ...
# 9306                                ROLEXESH               2018-03-02
# 5930                                 Circles               2020-01-17
# 12080               Queen II (2011 Remaster)               1974-03-08
# 6336                               Legendary               2019-06-07
# 28751                        Rave After Rave               2015-03-16
#
#                                       playlist_name             playlist_id  \
# 26607  Soul Coffee (The Best Neo-Soul Mixtape ever)  16iNEskDatG5KbDV16F6LR
# 13974                                Permanent Wave  2ExyzXAbukW7I8bDqdGvPB
# 16643                                Punto Tropical  37i9dQZF1DWZ1FUX6sM67g
# 30884                                     Happy EDM  3d2JFEbvcx7p2CHkBaQeMZ
# 3370                          ELECTROPOP EN ESPAÑOL  3VfscqF7zq65IGKiYM3FS0
# ...                                             ...                     ...
# 9306                                    GANGSTA Rap  5GA8GDo7RQC3JEanT81B3g
# 5930                                Hip-Hop Central  37i9dQZF1DWY6tYEFs22tT
# 12080           The Queen - La Discografia Completa  3E88dLx4fgFYY70gdGzdnB
# 6336                                Hip-Hop Mixtape  37i9dQZF1DWVdgXTbYm2r0
# 28751                         BIG-ROOM NEVER DIES !  4QtO2XySphMOJt7pX0yaVi
#
#       playlist_genre  ... key  loudness  mode  speechiness  acousticness  \
# 26607            r&b  ...   0    -3.717     0       0.1830       0.16000
# 13974           rock  ...   6    -5.861     1       0.0355       0.10700
# 16643          latin  ...   8    -7.158     0       0.0322       0.25900
# 30884            edm  ...   7    -3.131     1       0.0379       0.06640
# 3370             pop  ...   1    -6.437     0       0.0382       0.02630
# ...              ...  ...  ..       ...   ...          ...           ...
# 9306             rap  ...   8    -6.356     1       0.2240       0.29300
# 5930             rap  ...   2   -11.198     1       0.1490       0.47400
# 12080           rock  ...   2    -9.629     1       0.0928       0.40500
# 6336             rap  ...   9    -3.692     1       0.1140       0.07780
# 28751            edm  ...   6    -3.214     0       0.0837       0.00419
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 26607          0.000079    0.0765    0.600  121.778       230800
# 13974          0.000005    0.1180    0.513  103.272       229587
# 16643          0.000000    0.2950    0.598  110.039       207273
# 30884          0.000003    0.3130    0.251  128.959       228837
# 3370           0.119000    0.0945    0.783  105.013       223933
# ...                 ...       ...      ...      ...          ...
# 9306           0.000000    0.3860    0.638  119.887       290400
# 5930           0.000871    0.0640    0.336   68.985       298440
# 12080          0.007440    0.5500    0.255  108.592       248453
# 6336           0.000000    0.0608    0.349  102.956       160877
# 28751          0.005350    0.3660    0.468  128.055       161953
#
# [16000 rows x 23 columns]
